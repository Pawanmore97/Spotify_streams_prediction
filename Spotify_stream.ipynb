# %% [markdown]
# **Track**: name of the song, as visible on the Spotify platform.
# Artist: name of the artist.
#
# **Url_spotify**: the Url of the artist.
#
# **Album**: the album in wich the song is contained on Spotify.
#
# **Album_type**: indicates if the song is relesead on Spotify as a
# single or contained in an album.
#
# **Uri**: a spotify link used to find the song through the API.
#
# **Danceability**: describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# **Energy**: is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# **Key**: the key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
#
# **Loudness**: the overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
#
# **Speechiness**: detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# **Acousticness**: a confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# Instrumentalness: predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
# Liveness: detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# **Valence**: a measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# **Tempo**: the overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# **Duration_ms**: the duration of the track in milliseconds.
# Stream: number of streams of the song on Spotify.
#
# **Url_youtube**: url of the video linked to the song on Youtube, if it have any.
#
# **Title**: title of the videoclip on youtube.
#
# **Channel**: name of the channel that have published the video.
#
# **Views**: number of views.
#
# **Likes**: number of likes.
#
# **Comments**: number of comments.
#
# **Description**: description of the video on Youtube.
#
# **Licensed**: Indicates whether the video represents licensed content, which means that the content was uploaded to a channel linked to a YouTube content partner and then claimed by that partner.
#
# **official_video**: boolean value that indicates if the video found is the official video of the song.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
import seaborn as sb
import warnings

# %%
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None)

# %%
df =pd.read_csv("/content/Spotify_Youtube.csv",index_col= 0)

# %%
df.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %%
df.tail()
# Out:
#             Artist                                        Url_spotify  \
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#       Album_type                                   Uri  Danceability  Energy  \
# ...

# %%
df.shape
# Out:
# (20718, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20718 entries, 0 to 20717
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20718 non-null  object
#  1   Url_spotify       20718 non-null  object
#  2   Track             20718 non-null  object
#  3   Album             20718 non-null  object
#  4   Album_type        20718 non-null  object
#  5   Uri               20718 non-null  object
#  6   Danceability      20716 non-null  float64
#  7   Energy            20716 non-null  float64
#  8   Key               20716 non-null  float64
#  9   Loudness          20716 non-null  float64
#  10  Speechiness       20716 non-null  float64
#  11  Acousticness      20716 non-null  float64
#  12  Instrumentalness  20716 non-null  float64
#  13  Liveness          20716 non-null  float64
#  14  Valence           20716 non-null  float64
#  15  Tempo             20716 non-null  float64
# ...

# %%
df = df.drop(["Artist","Url_spotify","Track","Album","Uri","Url_youtube","Title","Channel","Comments","Description"],axis = 1)

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Stream              576
# Likes               541
# official_video      470
# Licensed            470
# Views               470
# Valence               2
# Duration_ms           2
# Tempo                 2
# Liveness              2
# Danceability          2
# Instrumentalness      2
# Acousticness          2
# Speechiness           2
# Loudness              2
# Key                   2
# Energy                2
# Album_type            0
# dtype: int64

# %%
sum(df.isnull().sum().sort_values(ascending = False))
# Out:
# 2549

# %%
sum(df.isnull().sum().sort_values(ascending = False))/df.shape[0]*100
# Out:
# 12.303311130417995

# %%
mpl.figure(figsize = (7,7))
sb.heatmap(df.isnull(),cmap = "rainbow",cbar = True)
mpl.title("Null Values Visualization")
mpl.show()

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Album_type          0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Views               0
# Likes               0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
df.shape
# Out:
# (19624, 17)

# %%
cat_var = [i for i in df.columns if df[i].dtype == "O"]
print(cat_var)
# Out:
# ['Album_type', 'Licensed', 'official_video']

# %%
for j in cat_var:
  print("Column:-",j)
  print(df[j].value_counts())
  sb.countplot(x = j,data =df)
  mpl.show()
  print("-"*80)
  print("")
# Out:
# Column:- Album_type
# album          14208
# single          4701
# compilation      715
# Name: Album_type, dtype: int64
# --------------------------------------------------------------------------------
#
# Column:- Licensed
# True     13757
# False     5867
# Name: Licensed, dtype: int64
# --------------------------------------------------------------------------------
#
# Column:- official_video
# True     15299
# False     4325
# Name: official_video, dtype: int64
# --------------------------------------------------------------------------------

# %%
num_var = [k for k in df.columns if df[k].dtype == "int" or df[k].dtype == "float64"]
print(num_var)
len(num_var)
# Out:
# ['Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo', 'Duration_ms', 'Views', 'Likes', 'Stream']
# 14

# %%
fig = mpl.figure(figsize=(20,20))
gs = fig.add_gridspec(5,5)

gs.update(wspace=0.25, hspace=0.25)

ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[0, 2])
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])
ax5 = fig.add_subplot(gs[1, 2])
ax6 = fig.add_subplot(gs[2, 0])
ax7 = fig.add_subplot(gs[2, 1])
ax8 = fig.add_subplot(gs[2, 2])
ax9 = fig.add_subplot(gs[3, 0])
ax10 = fig.add_subplot(gs[3, 1])
ax11 = fig.add_subplot(gs[3, 2])
ax12 = fig.add_subplot(gs[4, 0])

Axis = [ax0,ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9,ax10,ax11,ax12]
for i,col in zip(Axis,num_var):
  if col != "Stream":
    sb.boxplot(ax = i,y = col,data = df)
mpl.show()

# %%
fig = mpl.figure(figsize=(20,20))

gs = fig.add_gridspec(5,5)

gs.update(wspace=0.25, hspace=0.25)

ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[0, 2])
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])
ax5 = fig.add_subplot(gs[1, 2])
ax6 = fig.add_subplot(gs[2, 0])
ax7 = fig.add_subplot(gs[2, 1])
ax8 = fig.add_subplot(gs[2, 2])
ax9 = fig.add_subplot(gs[3, 0])
ax10 = fig.add_subplot(gs[3, 1])
ax11 = fig.add_subplot(gs[3, 2])
ax12 = fig.add_subplot(gs[4, 0])

Axis = [ax0,ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9,ax10,ax11,ax12]
for i,col in zip(Axis,num_var):
  if col != "Stream":
    sb.scatterplot(ax = i,x = col,y = "Stream",data = df,)
mpl.show()

# %%
mpl.figure(figsize = (10,10))
sb.heatmap(df[num_var].corr(),annot = True,fmt = ".2f")
mpl.show()

# %% [markdown]
# ## **Feature Engineering**

# %%
from sklearn.model_selection import train_test_split
X = df.drop("Stream",axis = 1)
y = df["Stream"]
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 42,test_size = 0.3)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (13736, 16)
# (5888, 16)
# (13736,)
# (5888,)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,StandardScaler,RobustScaler,OrdinalEncoder

# %%
tfm1 = ColumnTransformer(transformers = [
    ("Album_type",OneHotEncoder(drop = 'first'),[0]),
    ("Licensed",OneHotEncoder(drop = 'first'),[14]),
    ("official_video",OneHotEncoder(drop = 'first'),[15]),
],remainder = "passthrough")

# %%
tfm2 = ColumnTransformer(transformers =[
    ("Danceability",RobustScaler(),[3]),
    ("Energy",RobustScaler(),[4]),
    ("Key",StandardScaler(),[5]),
    ("Loudness",RobustScaler(),[6]),
    ("Speechiness",RobustScaler(),[7]),
    ("Acousticness",StandardScaler(),[8]),
    ("Instrumentalness",RobustScaler(),[9]),
    ("Liveness",RobustScaler(),[10]),
    ("Valence",StandardScaler(),[11]),
    ("Tempo",RobustScaler(),[12]),
    ("Duration_ms",RobustScaler(),[13]),
    ("Views",RobustScaler(),[14]),
    ("Likes",RobustScaler(),[15]),
],remainder = "passthrough")

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr_pipe = Pipeline([
    ("tmf1",tfm1),
    ("tmf2",tfm2),
    ("lr",lr)
])

# %%
lr_model = lr_pipe.fit(X_train,y_train)
lr_model
# Out:
# Pipeline(steps=[('tmf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Album_type',
#                                                   OneHotEncoder(drop='first'),
#                                                   [0]),
#                                                  ('Licensed',
#                                                   OneHotEncoder(drop='first'),
#                                                   [14]),
#                                                  ('official_video',
#                                                   OneHotEncoder(drop='first'),
#                                                   [15])])),
#                 ('tmf2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Danceability',
#                                                   RobustScaler(), [3]),
# ...

# %%
y_pred = lr_pipe.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
print(f"R2_score = {r2_score(y_test,y_pred)}")
print(f"Root Mean Squared Error = {np.sqrt(mean_squared_error(y_test,y_pred))}")
print(f"Mean Absolute Error = {mean_absolute_error(y_test,y_pred)}")
# Out:
# R2_score = 0.42063510324482356
# Root Mean Squared Error = 183750027.66483113
# Mean Absolute Error = 99410316.96839856

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
pl = PolynomialFeatures(degree=2)

# %%
poly_pipe = Pipeline([
    ('tfm1',tfm1),
    ('tfm2',tfm2),
    ("pl",pl)
])

X_train_tfm = poly_pipe.fit_transform(X_train)
X_test_tfm = poly_pipe.transform(X_test)

# %%
pl_reg = lr.fit(X_train_tfm,y_train)
pl_reg
# Out:
# LinearRegression()

# %%
poly_y_pred = lr.predict(X_test_tfm)

# %%
print(f"R2_score = {r2_score(y_test,poly_y_pred)}")
print(f"Root Mean Squared Error = {np.sqrt(mean_squared_error(y_test,poly_y_pred))}")
print(f"Mean Absolute Error = {mean_absolute_error(y_test,poly_y_pred)}")
# Out:
# R2_score = 0.5420851017690821
# Root Mean Squared Error = 163359242.4690767
# Mean Absolute Error = 89983157.12000655

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 200,criterion = "squared_error",
                           min_samples_split = 20,max_depth = 5)

# %%
rf_pipe = Pipeline([
    ('tfm1',tfm1),
    ('tfm2',tfm2),
    ("rf",rf)
])
rf_model = rf_pipe.fit(X_train,y_train)

# %%
rf_y_pred = rf_model.predict(X_test)

# %%
print(f"R2_score = {r2_score(y_test,rf_y_pred)}")
print(f"Root Mean Squared Error = {np.sqrt(mean_squared_error(y_test,rf_y_pred))}")
print(f"Mean Absolute Error = {mean_absolute_error(y_test,rf_y_pred)}")
# Out:
# R2_score = 0.5417082065323024
# Root Mean Squared Error = 163426456.54846174
# Mean Absolute Error = 89523172.61414754

# %% [markdown]
# ## **KNN**

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()

knn_pipe = Pipeline([
    ('tfm1',tfm1),
    ('tfm2',tfm2),
    ("knn",knn)
])
knn_model = knn_pipe.fit(X_train,y_train)

knn_y_pred = knn_model.predict(X_test)

# %%
print(f"R2_score = {r2_score(y_test,knn_y_pred)}")
print(f"Root Mean Squared Error = {np.sqrt(mean_squared_error(y_test,knn_y_pred))}")
print(f"Mean Absolute Error = {mean_absolute_error(y_test,knn_y_pred)}")
# Out:
# R2_score = 0.3990475176235354
# Root Mean Squared Error = 187142053.56949311
# Mean Absolute Error = 101347243.89904891

# %% [markdown]
# ## **AdaBoost**

# %%
from sklearn.ensemble import AdaBoostRegressor
ab = AdaBoostRegressor(n_estimators=100)

ab_pipe = Pipeline([
    ('tfm1',tfm1),
    ('tfm2',tfm2),
    ("ab",ab)
])
ab_model = ab_pipe.fit(X_train,y_train)

ab_y_pred = ab_model.predict(X_test)

# %%
print(f"R2_score = {r2_score(y_test,ab_y_pred)}")
print(f"Root Mean Squared Error = {np.sqrt(mean_squared_error(y_test,ab_y_pred))}")
print(f"Mean Absolute Error = {mean_absolute_error(y_test,ab_y_pred)}")
# Out:
# R2_score = -3.536188295239656
# Root Mean Squared Error = 514158311.76523703
# Mean Absolute Error = 490855097.67330766

# %% [markdown]
# ## **Gradient Boost**

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor(n_estimators=200,loss = "squared_error",learning_rate = 0.5,max_depth = 5)

gb_pipe = Pipeline([
    ('tfm1',tfm1),
    ('tfm2',tfm2),
    ("gb",gb)
])
gb_model = gb_pipe.fit(X_train,y_train)

gb_y_pred = gb_model.predict(X_test)

# %%
print(f"R2_score = {r2_score(y_test,gb_y_pred)}")
print(f"Root Mean Squared Error = {np.sqrt(mean_squared_error(y_test,gb_y_pred))}")
print(f"Mean Absolute Error = {mean_absolute_error(y_test,gb_y_pred)}")
# Out:
# R2_score = 0.47691191500326935
# Root Mean Squared Error = 174597788.2631568
# Mean Absolute Error = 93310102.44683087

# %% [markdown]
# ## **XG Boost**

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor(n_estimators=200,)

xgb_pipe = Pipeline([
    ('tfm1',tfm1),
    ('tfm2',tfm2),
    ("xgb",xgb)
])
xgb_model = xgb_pipe.fit(X_train,y_train)

xgb_y_pred = xgb_model.predict(X_test)

# %%
print(f"R2_score = {r2_score(y_test,gb_y_pred)}")
print(f"Root Mean Squared Error = {np.sqrt(mean_squared_error(y_test,gb_y_pred))}")
print(f"Mean Absolute Error = {mean_absolute_error(y_test,gb_y_pred)}")
# Out:
# R2_score = 0.47691191500326935
# Root Mean Squared Error = 174597788.2631568
# Mean Absolute Error = 93310102.44683087

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
xg_params = [{
    "xgb__n_estimators":[50,100,200,300],
    "xgb__learning_rate":[0.001,0.01,0.1],
    "xgb__max_depth":[5,10,15],
}]

Xgb_model = RandomizedSearchCV(xgb_pipe,xg_params,cv = 10,scoring = "r2")
Xgb_model.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=10,
#                    estimator=Pipeline(steps=[('tfm1',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('Album_type',
#                                                                                OneHotEncoder(drop='first'),
#                                                                                [0]),
#                                                                               ('Licensed',
#                                                                                OneHotEncoder(drop='first'),
#                                                                                [14]),
#                                                                               ('official_video',
#                                                                                OneHotEncoder(drop='first'),
# ...

# %%
Xgb_model.best_params_
# Out:
# {'xgb__n_estimators': 200, 'xgb__max_depth': 10, 'xgb__learning_rate': 0.1}

# %%
Xgb_model.best_score_
# Out:
# 0.570466065733513
